# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
data=pd.read_csv("Zomato-data-.csv")

# %%
data.head()
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
data.tail()
# Out:
#                  name online_order book_table   rate  votes  \
# 143  Melting Melodies           No         No  3.3/5      0
# 144   New Indraprasta           No         No  3.3/5      0
# 145      Anna Kuteera          Yes         No  4.0/5    771
# 146            Darbar           No         No  3.0/5     98
# 147     Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 143                          100          Dining
# 144                          150          Dining
# 145                          450          Dining
# 146                          800          Dining
# 147                          200          Dining

# %%
data.shape
# Out:
# (148, 7)

# %%
data.size
# Out:
# 1036

# %%
data.isnull().sum()
# Out:
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# approx_cost(for two people)    0
# listed_in(type)                0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    object
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 8.2+ KB

# %%
def handleRate(value):
    value=str(value).split('/')
    value=value[0];
    return float(value)

data['rate']=data['rate'].apply(handleRate)
print(data.head())
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
data.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    float64
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 8.2+ KB

# %%
data.isnull().sum()
# Out:
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# approx_cost(for two people)    0
# listed_in(type)                0
# dtype: int64

# %%
sb.countplot(x=data['listed_in(type)'])
plt.xlabel("Type of Restuarent")
# Out:
# Text(0.5, 0, 'Type of Restuarent')

# %%
sb.countplot(x=data['online_order'])
plt.xlabel('Online Order')
# Out:
# Text(0.5, 0, 'Online Order')

# %%
sb.countplot(x=data['book_table'])
plt.xlabel('Book Table ')
# Out:
# Text(0.5, 0, 'Book Table ')

# %%
sb.countplot(x=data['votes'])
plt.xlabel('Votes graph')
# Out:
# Text(0.5, 0, 'Votes graph')

# %%
group_data=data.groupby('listed_in(type)')['votes'].sum()
result=pd.DataFrame({'votes': grouped_data})
plt.plot(result, c='green', marker='o')
plt.xlabel('Type of restuarent', c='red', size=20)
plt.ylabel('Votes', c='red', size=20)
# Out:
# Text(0, 0.5, 'Votes')

# %%
maximum_vote=data['votes'].max()

# %%
maximum_vote
restuarent_with_max_votes=data.loc[data['votes']==maximum_vote, 'name']

# %%
restuarent_with_max_votes
# Out:
# 38    Empire Restaurant
# Name: name, dtype: object

# %%
plt.hist(data['rate'], bins=5)
plt.title('Rating Distribution')
plt.show()

# %%
couple_data=data['approx_cost(for two people)']

# %%
sb.countplot(x=couple_data)
# Out:
# <AxesSubplot: xlabel='approx_cost(for two people)', ylabel='count'>

# %%
plt.figure(figsize=(6,6))
sb.boxplot(x='online_order', y='rate', data=data)
# Out:
# <AxesSubplot: xlabel='online_order', ylabel='rate'>

# %%
pivot_table = data.pivot_table(index='listed_in(type)', columns='online_order', aggfunc='size', fill_value=0)
sb.heatmap(pivot_table, annot=True, cmap='YlGnBu', fmt='d')
plt.title('Heatmap')
plt.xlabel('Online Order')
plt.ylabel('Listed In (Type)')
plt.show()
