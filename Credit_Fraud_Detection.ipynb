# %%
import random

def credit_card_csv_file():
  """Generates a credit card CSV file with 10 random credit card numbers."""

  with open("credit_card_data.csv", "w") as f:
    f.write("credit_card_number,transaction_date,transaction_amount,month,merchant_name,merchant_location,transaction_type,authorization_code\n")
    for i in range(100):
      credit_card_number = "4" + "".join([str(random.randint(10, 99)) for _ in range(15)])
      transaction_date = "2023-08-" + "".join([str(random.randint(1, 28)) for _ in range(2)])
      transaction_amount = random.randint(100, 1000)
      merchant_name = "Merchant " + str(i)
      merchant_location = "Location " + str(i)
      transaction_type = "Purchase"
      authorization_code = str(random.randint(1000, 9999))
      month="Month " + str(i)
      f.write(f"{credit_card_number},{transaction_date},{transaction_amount},{month},{merchant_name},{merchant_location},{transaction_type},{authorization_code}\n")


credit_card_csv_file()

# %%
import pandas as pd
credit_data=pd.read_csv("credit_card_data.csv")

# %%
credit_data
# Out:
#                  credit_card_number transaction_date  transaction_amount  \
# 0   4756474778789525822318232716577     2023-08-1216                 292
# 1   4478934264548774031529035846117      2023-08-207                 487
# 2   4749811203425159380117620853281       2023-08-11                 770
# 3   4145920526840311816196834134056      2023-08-220                 176
# 4   4847687758986883282487222593112       2023-08-92                 415
# ..                              ...              ...                 ...
# 95  4893255256336274299124740811332     2023-08-2223                 646
# 96  4682777458418843691282818485886     2023-08-1411                 127
# 97  4678973968257386255306318801716      2023-08-184                 285
# 98  4366388659426668142594853836991     2023-08-2612                 990
# 99  4119187617880534686551948793065     2023-08-2628                 292
#
#        month merchant_name merchant_location transaction_type  \
# ...

# %%
credit_data.head()
# Out:
#                 credit_card_number transaction_date  transaction_amount  \
# 0  4756474778789525822318232716577     2023-08-1216                 292
# 1  4478934264548774031529035846117      2023-08-207                 487
# 2  4749811203425159380117620853281       2023-08-11                 770
# 3  4145920526840311816196834134056      2023-08-220                 176
# 4  4847687758986883282487222593112       2023-08-92                 415
#
#      month merchant_name merchant_location transaction_type  \
# 0  Month 0    Merchant 0        Location 0         Purchase
# 1  Month 1    Merchant 1        Location 1         Purchase
# 2  Month 2    Merchant 2        Location 2         Purchase
# 3  Month 3    Merchant 3        Location 3         Purchase
# 4  Month 4    Merchant 4        Location 4         Purchase
#
#    authorization_code
# 0                1191
# 1                1216
# 2                8891
# 3                4670
# 4                9797

# %%
credit_data.shape
# Out:
# (100, 8)

# %%
credit_data.size
# Out:
# 800

# %%
credit_data.columns
# Out:
# Index(['credit_card_number', 'transaction_date', 'transaction_amount', 'month',
#        'merchant_name', 'merchant_location', 'transaction_type',
#        'authorization_code'],
#       dtype='object')

# %%
credit_data.describe()
# Out:
#        transaction_amount  authorization_code
# count          100.000000          100.000000
# mean           534.370000         5865.940000
# std            259.625747         2729.232074
# min            125.000000         1022.000000
# 25%            293.500000         3681.000000
# 50%            484.000000         5750.500000
# 75%            735.250000         8303.250000
# max            990.000000         9997.000000

# %%
credit_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   credit_card_number  100 non-null    object
#  1   transaction_date    100 non-null    object
#  2   transaction_amount  100 non-null    int64
#  3   month               100 non-null    object
#  4   merchant_name       100 non-null    object
#  5   merchant_location   100 non-null    object
#  6   transaction_type    100 non-null    object
#  7   authorization_code  100 non-null    int64
# dtypes: int64(2), object(6)
# memory usage: 6.4+ KB

# %%
credit_data.isnull().sum()
# Out:
# credit_card_number    0
# transaction_date      0
# transaction_amount    0
# month                 0
# merchant_name         0
# merchant_location     0
# transaction_type      0
# authorization_code    0
# dtype: int64

# %%
credit_data.count()
# Out:
# credit_card_number    100
# transaction_date      100
# transaction_amount    100
# month                 100
# merchant_name         100
# merchant_location     100
# transaction_type      100
# authorization_code    100
# dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import seaborn as sb
from sklearn import metrics
from sklearn import linear_model
from sklearn import model_selection
from sklearn import ensemble
from sklearn import feature_selection
from sklearn import feature_extraction
from sklearn import naive_bayes
from sklearn import svm
from sklearn.svm import SVC
from sklearn import preprocessing
from sklearn import pipeline
from sklearn import tree
import xgboost
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix

# %%
credit_data.isna().any()
# Out:
# credit_card_number    False
# transaction_date      False
# transaction_amount    False
# month                 False
# merchant_name         False
# merchant_location     False
# transaction_type      False
# authorization_code    False
# dtype: bool

# %%
null_columns=pd.DataFrame({"Columns": credit_data.isna().sum().index, "Nonexistent":credit_data.isna().sum().values,"Percentage": credit_data.isna().sum().values/credit_data.shape[0]})

# %%
null_columns
# Out:
#               Columns  Nonexistent  Percentage
# 0  credit_card_number            0         0.0
# 1    transaction_date            0         0.0
# 2  transaction_amount            0         0.0
# 3               month            0         0.0
# 4       merchant_name            0         0.0
# 5   merchant_location            0         0.0
# 6    transaction_type            0         0.0
# 7  authorization_code            0         0.0

# %%
null_columns['Columns'].head(5)
# Out:
# 0    credit_card_number
# 1      transaction_date
# 2    transaction_amount
# 3                 month
# 4         merchant_name
# Name: Columns, dtype: object

# %%
ncount=0
legitimate=credit_data['credit_card_number']
for i in range(len(legitimate)):
    if legitimate[i]==0:
        ncount=ncount+1
ncount
# Out:
# 0

# %%
prnf=(ncount/len(legitimate))*100

# %%
prnf
# Out:
# 0.0

# %%
credit_data.hist(grid=False,bins=10,figsize=(10,10))
plt.show()

# %%
plt.bar(credit_data['merchant_name'],credit_data['transaction_amount'])
# Out:
# <BarContainer object of 100 artists>

# %%
plt.bar(credit_data['merchant_name'],credit_data['transaction_amount'])
plt.xlabel('Merchant Name')
plt.ylabel('Transaction Amount')
# Out:
# Text(0, 0.5, 'Transaction Amount')

# %%
x=credit_data['transaction_amount']
y=credit_data['transaction_date']
plt.plot(x,y)
plt.title('TIme vs Amount')
# Out:
# Text(0.5, 1.0, 'TIme vs Amount')

# %%
x=credit_data['transaction_amount']
y=credit_data['transaction_date']
plt.plot(y,x)
plt.title('TIme vs Amount')
# Out:
# Text(0.5, 1.0, 'TIme vs Amount')

# %%
plt.figure(figsize=(10,10))
sb.displot(credit_data['transaction_amount'],color='red')
plt.title("Transaction Amount Distribution")
# Out:
# Text(0.5, 1.0, 'Transaction Amount Distribution')

# %%
plt.figure(figsize=(10,10))
sb.displot(credit_data['transaction_amount'],color='blue')
plt.title("Transaction Amount Distribution")
# Out:
# Text(0.5, 1.0, 'Transaction Amount Distribution')

# %%
fig,ax=plt.subplots(figsize=(10,10))
ax.scatter(credit_data['transaction_amount'],credit_data['transaction_date'])
ax.set_xlabel('Amount')
ax.set_ylabel('Date')
plt.show()

# %%
x=credit_data.drop(['credit_card_number'],axis=1)
y=credit_data['transaction_amount']

xtrain, xtest, ytrain, ytest=train_test_split(x, y, random_state=40, test_size=0.4)

# %%
lgr=LogisticRegression()

# %%
corrmat = credit_data.corr()
fig = plt.figure(figsize = (12, 9))
sb.heatmap(corrmat, vmax = .8, square = True)
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
rcf=RandomForestClassifier()

# %%
LABELS = ['Normal', 'Fraud']
conf_matrix = confusion_matrix(yTest, yPred)
plt.figure(figsize =(12, 12))
sns.heatmap(conf_matrix, xticklabels = LABELS, 
            yticklabels = LABELS, annot = True, fmt ="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

# %%
from sklearn.metrics import classification_report, accuracy_score 
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score, matthews_corrcoef
from sklearn.metrics import confusion_matrix
  
n_outliers = len(fraud)
n_errors = (yPred != yTest).sum()
print("The model used is Random Forest classifier")
  
acc = accuracy_score(yTest, yPred)
print("The accuracy is {}".format(acc))
  
prec = precision_score(yTest, yPred)
print("The precision is {}".format(prec))
  
rec = recall_score(yTest, yPred)
print("The recall is {}".format(rec))
  
f1 = f1_score(yTest, yPred)
print("The F1-Score is {}".format(f1))
  
MCC = matthews_corrcoef(yTest, yPred)
print("The Matthews correlation coefficient is{}".format(MCC))
